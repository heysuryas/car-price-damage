# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_csv('/Users/NeethuJose/Downloads/used_cars_data.csv')



sns.set(style="ticks")
sns.pairplot(df, x_vars=df.columns[:-1], y_vars='price', height=2.5, aspect=2.5)
plt.show()
